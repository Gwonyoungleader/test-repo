# %% [markdown]
# # TPC AI 튜토리얼 세션 설계안 (한국어)
#
# > 요청 반영: 문서형 안내도 notebook으로 통일.

# %% [markdown]
# ## 세션 1) PID + 물리 개념 + TPC 개요
# - Bethe-Bloch 의미: 입자별 dE/dx 차이
# - Geant4 process 에너지 대역별 개념
#   - 저에너지: 광전효과
#   - 중간: 콤프턴 산란
#   - 고에너지: 쌍생성/소멸
# - 코드 대응: physics list / track-step 반영 경로 확인

# %% [markdown]
# ## 세션 2) Raw/digi branch + Feature
# - 입력: `MCTrack`, `MCVertex`, `MCStepTPCDrum`
# - chain: `STDDriftElectronMaker -> STDElectronicsMaker -> STDNoiseSubtractor -> STDPulseAnalyser`
# - 출력: `RawPad`, `Hit`, `StepTruth`, `RecoSummary`, `HitTruth`

# %% [markdown]
# ## 세션 3) 전처리 + Fitting method/HT + 시각화
# - `Fitting method`: Hit.x vs Hit.y least-squares line
# - HT와 truth 비교 및 한계 설명

# %% [markdown]
# ## 세션 4~8) 데이터셋/손실함수/CNN/분할/최종 시각화
# - truth, digi, csv의 역할 분리
# - MSE/RMSE/MAE와 모델 선택 기준
# - train/valid/test event 단위 분리
# - 최종 비교: HT/Fitting method/AI vs truth

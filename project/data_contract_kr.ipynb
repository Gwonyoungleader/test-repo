# %% [markdown]
# # 업로드/연동 체크리스트 (Notebook)
#
# 아래 항목을 올려주시면 다음 단계 코드를 바로 이어서 작성 가능합니다.

# %% [markdown]
# ## 1) 필수 데이터
# - truth ROOT (`run_XXX.root`)
# - digi ROOT (`run_XXX_digi.root`)
# - `tpcd_ai_event.csv`

# %% [markdown]
# ## 2) 필수 클래스/헤더
# - `TPCDStepTruthTask` 소스/헤더
# - `TPCDRecoSummaryTask` 소스/헤더
# - `TPCDHitTruthTask` 소스/헤더
# - `STDPulseAnalyser` Hit 생성 로직
# - `GetCoordinateGeantToPad()` 정의/호출 위치

# %% [markdown]
# ## 3) 매크로
# - `CompareHTWithFittingAndAI_Heavy.C`
# - `makeHoyleAlphaPairTripleEngine.C`
# - `inspectSimFiles.C`, `exportTPCDToCSV.C`
